# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
df = pd.read_csv("enhanced_zomato_dataset_clean.csv", encoding="latin1")

# %%
df.head()
# Out:
#   Restaurant_Name  Dining_Rating  Delivery_Rating  Dining_Votes  \
# 0      Doner King            3.9              4.2            39
# 1      Doner King            3.9              4.2            39
# 2      Doner King            3.9              4.2            39
# 3      Doner King            3.9              4.2            39
# 4      Doner King            3.9              4.2            39
#
#    Delivery_Votes    Cuisine Place_Name        City                 Item_Name  \
# 0               0  Fast Food   Malakpet   Hyderabad       Platter Kebab Combo
# 1               0  Fast Food   Malakpet   Hyderabad   Chicken Rumali Shawarma
# 2               0  Fast Food   Malakpet   Hyderabad    Chicken Tandoori Salad
# 3               0  Fast Food   Malakpet   Hyderabad         Chicken BBQ Salad
# 4               0  Fast Food   Malakpet   Hyderabad  Special Doner Wrap Combo
#
#   Best_Seller  ...  Is_Bestseller  Restaurant_Popularity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123657 entries, 0 to 123656
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Restaurant_Name        123657 non-null  object
#  1   Dining_Rating          123657 non-null  float64
#  2   Delivery_Rating        123657 non-null  float64
#  3   Dining_Votes           123657 non-null  int64
#  4   Delivery_Votes         123657 non-null  int64
#  5   Cuisine                123657 non-null  object
#  6   Place_Name             123657 non-null  object
#  7   City                   123657 non-null  object
#  8   Item_Name              123657 non-null  object
#  9   Best_Seller            123657 non-null  object
#  10  Votes                  123657 non-null  int64
#  11  Prices                 123657 non-null  float64
#  12  Average_Rating         123657 non-null  float64
#  13  Total_Votes            123657 non-null  int64
# ...

# %%
df.describe()
# Out:
#        Dining_Rating  Delivery_Rating   Dining_Votes  Delivery_Votes  \
# count  123657.000000    123657.000000  123657.000000   123657.000000
# mean        3.822264         3.963184     152.729858      115.763725
# std         0.351407         0.244624     232.214061      243.970828
# min         2.500000         2.500000       0.000000        0.000000
# 25%         3.700000         3.800000       0.000000        0.000000
# 50%         3.822264         4.000000      30.000000        0.000000
# 75%         4.000000         4.100000     217.000000       23.000000
# max         4.800000         4.600000     997.000000      983.000000
#
#                Votes         Prices  Average_Rating    Total_Votes  \
# count  123657.000000  123657.000000   123657.000000  123657.000000
# mean       24.666772     241.378399        3.892724     268.493583
# std       125.236009     192.830713        0.238449     292.811830
# min         0.000000       0.950000        3.000000       0.000000
# ...

# %%
df.columns
# Out:
# Index(['Restaurant_Name', 'Dining_Rating', 'Delivery_Rating', 'Dining_Votes',
#        'Delivery_Votes', 'Cuisine', 'Place_Name', 'City', 'Item_Name',
#        'Best_Seller', 'Votes', 'Prices', 'Average_Rating', 'Total_Votes',
#        'Price_per_Vote', 'Log_Price', 'Is_Bestseller', 'Restaurant_Popularity',
#        'Avg_Rating_Restaurant', 'Avg_Price_Restaurant', 'Avg_Rating_Cuisine',
#        'Avg_Price_Cuisine', 'Avg_Rating_City', 'Avg_Price_City',
#        'Is_Highly_Rated', 'Is_Expensive'],
#       dtype='object')

# %%
df = df.drop(columns=[
    'Restaurant_Name', 'Dining_Rating', 'Cuisine',
    'Is_Highly_Rated', 'Item_Name', 'Delivery_Rating', 'Votes'
], errors='ignore')  # errors='ignore' varsa problem yaratmaz

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# dining_votes             0
# delivery_votes           0
# place_name               0
# city                     0
# best_seller              0
# prices                   0
# average_rating           0
# total_votes              0
# price_per_vote           0
# log_price                0
# is_bestseller            0
# restaurant_popularity    0
# avg_rating_restaurant    0
# avg_price_restaurant     0
# avg_rating_cuisine       0
# avg_price_cuisine        0
# avg_rating_city          0
# avg_price_city           0
# is_expensive             0
# dtype: int64

# %%
df['city'].value_counts().head(10).plot(kind='bar', figsize=(10,5), title='En Çok Restoran Bulunan 10 Şehir')
plt.ylabel("Restoran Sayısı")
plt.show()

# %%
df.groupby('city')['avg_rating_city'].mean().sort_values(ascending=False).head(10).plot(
    kind='bar', figsize=(10,6), color='green'
)
plt.title('Ortalama Puanı En Yüksek 10 Şehir')
plt.ylabel('Ortalama Puan')
plt.xticks(rotation=45)
plt.ylim(0, 5)
plt.show()

# %%
print(df.columns)
# Out:
# Index(['dining_votes', 'delivery_votes', 'place_name', 'city', 'best_seller',
#        'prices', 'average_rating', 'total_votes', 'price_per_vote',
#        'log_price', 'is_bestseller', 'restaurant_popularity',
#        'avg_rating_restaurant', 'avg_price_restaurant', 'avg_rating_cuisine',
#        'avg_price_cuisine', 'avg_rating_city', 'avg_price_city',
#        'is_expensive'],
#       dtype='object')

# %%
df.groupby('city')['avg_price_city'].mean().sort_values(ascending=False).head(10).plot(
    kind='bar', figsize=(10,6), color='darkred'
)
plt.title('Ortalama Fiyatı En Yüksek 10 Şehir')
plt.ylabel('Fiyat')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='avg_price_restaurant', y='avg_rating_restaurant', alpha=0.6)
plt.title('Restoran Fiyatı ve Puanı İlişkisi')
plt.xlabel('Ortalama Fiyat (Restoran)')
plt.ylabel('Ortalama Puan (Restoran)')
plt.ylim(0, 5)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='is_expensive', y='avg_rating_restaurant')
plt.title('Pahalı Restoranların Ortalama Puanı')
plt.xlabel('Pahalı mı? (True/False)')
plt.ylabel('Ortalama Puan')
plt.ylim(0, 5)
plt.show()

# %%
df.groupby('best_seller')['avg_rating_cuisine'].mean().sort_values(ascending=False).head(10).plot(
    kind='bar', color='orange', figsize=(10,6)
)
plt.title('En Yüksek Puanlı Mutfaklar (Best Seller)')
plt.ylabel('Ortalama Puan')
plt.xticks(rotation=45)
plt.ylim(0, 5)
plt.show()

# %%
numeric_cols = df[['avg_rating_restaurant', 'avg_price_restaurant', 'avg_price_city', 'avg_rating_city']]

plt.figure(figsize=(8,6))
sns.heatmap(numeric_cols.corr(), annot=True, cmap='YlGnBu', fmt=".2f")
plt.title('Korelasyon Matrisi')
plt.show()
